# %% [markdown]
# # Predict Employee Burnout

# %% [markdown]
# ## 1. Business Problem and Understanding

# %%
# Import libraries

import pandas as pd
import numpy as np
import random
np.random.seed(42)
random.seed(42)
import matplotlib.pyplot as plt
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import root_mean_squared_error, ConfusionMatrixDisplay
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, \
GradientBoostingRegressor, VotingRegressor, StackingRegressor
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImPipeline
from xgboost import XGBRegressor
# import warnings
# warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. Data Understanding

# %%
# Import data

train = pd.read_csv('Data/train.csv')
test = pd.read_csv('Data/test.csv')
sample_submission = pd.read_csv('Data/sample_submission.csv')

# %%
# Combine train & test

full_df = pd.concat([train,test],axis=0)
full_df.head()
# Out:
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe32003000360033003200      2008-09-30  Female      Service
# 1      fffe3700360033003500      2008-11-30    Male      Service
# 2  fffe31003300320037003900      2008-03-10  Female      Product
# 3  fffe32003400380032003900      2008-11-03    Male      Service
# 4  fffe31003900340031003600      2008-07-24  Female      Service
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score  \
# 0                  No          2.0                  3.0                   3.8
# 1                 Yes          1.0                  2.0                   5.0
# 2                 Yes          2.0                  NaN                   5.8
# 3                 Yes          1.0                  1.0                   2.6
# 4                  No          3.0                  7.0                   6.9
#
#    Burn Rate
# 0       0.16
# 1       0.36
# 2       0.49
# 3       0.20
# 4       0.52

# %%
# Transform column names

full_df.columns = full_df.columns.str.lower()
full_df.columns = full_df.columns.str.replace(' ','_')

# %% [markdown]
# It looks like we have some missing values in the last 3 columns of the data set. With so much missing from the `burn_rate` we cannot drop those values, we would ideally impute on them.

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35000 entries, 0 to 12249
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           35000 non-null  object
#  1   date_of_joining       35000 non-null  object
#  2   gender                35000 non-null  object
#  3   company_type          35000 non-null  object
#  4   wfh_setup_available   35000 non-null  object
#  5   designation           35000 non-null  float64
#  6   resource_allocation   33619 non-null  float64
#  7   mental_fatigue_score  32883 non-null  float64
#  8   burn_rate             21626 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 2.7+ MB

# %%
full_df.isna().sum()/full_df.shape[0]*100
# Out:
# employee_id              0.000000
# date_of_joining          0.000000
# gender                   0.000000
# company_type             0.000000
# wfh_setup_available      0.000000
# designation              0.000000
# resource_allocation      3.945714
# mental_fatigue_score     6.048571
# burn_rate               38.211429
# dtype: float64

# %% [markdown]
# We can see that all numeri columns are a scale, `burn_rate`, our target is from 0-1. We may want to adjust that to be on a 1-10 scale as the other variables

# %%
full_df.describe()
# Out:
#         designation  resource_allocation  mental_fatigue_score     burn_rate
# count  35000.000000         33619.000000          32883.000000  21626.000000
# mean       2.177514             4.473185              5.725350      0.452005
# std        1.134339             2.046623              1.918292      0.198226
# min        0.000000             1.000000              0.000000      0.000000
# 25%        1.000000             3.000000              4.500000      0.310000
# 50%        2.000000             4.000000              5.900000      0.450000
# 75%        3.000000             6.000000              7.100000      0.590000
# max        5.000000            10.000000             10.000000      1.000000

# %% [markdown]
# ## 3. Data Exporation

# %% [markdown]
# It looks like all of the columns with missingness are mostly normally distributed, so we can confidently impute with the mean.

# %%
plt.hist(full_df['burn_rate']);

print('mean:',np.nanmean(full_df['burn_rate']))
print('median:',np.nanmedian(full_df['burn_rate']))
# Out:
# mean: 0.45200545639508
# median: 0.45

# %%
plt.hist(full_df['mental_fatigue_score']);

print('mean:',np.nanmean(full_df['mental_fatigue_score']))
print('median:',np.nanmedian(full_df['mental_fatigue_score']))
# Out:
# mean: 5.725350485053067
# median: 5.9

# %%
plt.hist(full_df['resource_allocation']);

print('mean:',np.nanmean(full_df['resource_allocation']))
print('median:',np.nanmedian(full_df['resource_allocation']))
# Out:
# mean: 4.4731848062107735
# median: 4.0

# %% [markdown]
# We also don't have any duplicates so we can drop `employee_id` along with `date_of_joining` since we are working with one year.

# %%
full_df.duplicated(subset=['employee_id']).value_counts()
# Out:
# False    35000
# Name: count, dtype: int64

# %% [markdown]
# ### Target Variable `burn_rate`
#
# Since we want to conduct a predictive model and better understand which employees are at risk of burnout, we will create a label column defining burnout. Since the metric was on a 0-1 scale, for ease of interpretation, we will increase this scale by 10 and round the number to the nearest whole number.
#
# It looks like we have a slight class imbalance which we should try to address.

# %%
full_df['burn_label'] = full_df['burn_rate'].apply(lambda x: round(x*10) if not np.isnan(x) else x)
full_df['burn_label'].value_counts()
# Out:
# burn_label
# 4.0     4509
# 5.0     3697
# 6.0     3627
# 3.0     2848
# 2.0     2203
# 7.0     1826
# 8.0     1047
# 1.0      869
# 0.0      524
# 9.0      318
# 10.0     158
# Name: count, dtype: int64

# %% [markdown]
# Unfortunately we have to drop the missing values in our target in order to split our data into train/test. This will reduce our dataset quite a bit but hopefully we can get decent results still.

# %%
print('Total size after dropping target nas:',full_df.shape[0])
print('Total missing values of target:',full_df['burn_label'].isna().sum())

y_nas_dropped = full_df.dropna(subset=['burn_label'])

print('Total size after dropping target nas:',y_nas_dropped.shape[0])
# Out:
# Total size after dropping target nas: 35000
# Total missing values of target: 13374
# Total size after dropping target nas: 21626

# %% [markdown]
# ## 4. Data Preperation

# %%
# Define X, y and split train/test

X = y_nas_dropped.drop(columns=['date_of_joining','employee_id','burn_label','burn_rate'])
y = y_nas_dropped['burn_label']

X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42, stratify=y)
X_train.isna().sum()
# Out:
# gender                     0
# company_type               0
# wfh_setup_available        0
# designation                0
# resource_allocation      939
# mental_fatigue_score    1504
# dtype: int64

# %%
# Define num and cat subpipes
subpipe_num = Pipeline(steps=[('num_impute', SimpleImputer()),
                           ('ss', StandardScaler())])
subpipe_cat = Pipeline(steps=[('ohe', OneHotEncoder(sparse_output=False, handle_unknown='ignore'))])

# Create column transformer
CT = ColumnTransformer(transformers=[('subpipe_num', subpipe_num, [3, 4, 5]),
                                         ('subpipe_cat', subpipe_cat, [0, 1, 2])],
                           remainder='passthrough')
# Initial pipeline
lr_pipe = Pipeline(steps=[('ct', CT),
                            ('model', LinearRegression())])
                            
lr_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('subpipe_num',
#                                                   Pipeline(steps=[('num_impute',
#                                                                    SimpleImputer()),
#                                                                   ('ss',
#                                                                    StandardScaler())]),
#                                                   [3, 4, 5]),
#                                                  ('subpipe_cat',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   [0, 1, 2])])),
#                 ('model', LinearRegression())])

# %%
# Baseline score

print('Train Score:', root_mean_squared_error(y_train,lr_pipe.predict(X_train)))
# Out:
# Train Score: 0.7760929532760552

# %% [markdown]
# ## 5. Linear Regression Model
#
# First, lets see if we can improve our LinearRegression model with testing out our Lasso and Ridge models.

# %% [markdown]
# ### Lasso

# %%
# Replace in pipeline

lasso_pipe = lr_pipe.set_params(model=Lasso())
lasso_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('subpipe_num',
#                                                   Pipeline(steps=[('num_impute',
#                                                                    SimpleImputer()),
#                                                                   ('ss',
#                                                                    StandardScaler())]),
#                                                   [3, 4, 5]),
#                                                  ('subpipe_cat',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   [0, 1, 2])])),
#                 ('model', Lasso())])

# %%
# Define your parameter grid
params = {
    'model__alpha':[.0001,.001,.01,1,10,100,1000],
    'model__selection': ['cyclic','random']
    
}

rcv=RandomizedSearchCV(lasso_pipe,param_distributions=params,scoring='neg_root_mean_squared_error',
                 return_train_score=True,cv=5,random_state=42,n_iter=15)

rcv.fit(X_train,y_train)
rcv.best_params_
# Out:
# /Users/elinarankova/anaconda3/envs/learn-env-lite-2/lib/python3.12/site-packages/sklearn/model_selection/_search.py:318: UserWarning: The total space of parameters 14 is smaller than n_iter=15. Running 14 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# {'model__selection': 'cyclic', 'model__alpha': 0.0001}

# %% [markdown]
# We actually did worse after cross validation. It looks like our model isn't over/under fitting so that's a bonus. We may want to try a different type of model next.

# %%
# Create quick function to see the scores easier for future models
def rcv_metrics(rcv,model_name,X,y,train_df=None):
    best_estimator = rcv.best_estimator_
    score_dict = {'Val Train Score': -np.mean(rcv.cv_results_['mean_train_score']),
                 'Val Test Score':-np.mean(rcv.cv_results_['mean_test_score']),
                 'Model Name': model_name}
    score_df = pd.DataFrame(score_dict,columns=['Model Name','Val Train Score',
                                                'Val Test Score'], index=range(1))
    if train_df is None:
        pass
    else:
       score_df = pd.concat([train_df,score_df])
       score_df.index = range(len(score_df))
    return score_df, best_estimator
    
train_scores, lasso_best = rcv_metrics(rcv,'Lasso',X_train,y_train)
train_scores
# Out:
#   Model Name  Val Train Score  Val Test Score
# 0      Lasso         1.382408        1.382881

# %% [markdown]
# Our score on our test is around the same as on our train, so we know there is no overfitting or underfitting.

# %%
# Function to dislay f1 score and confusion matrix
def test_metrics(model,model_name,X,y,test_df=None):
    score_dict = {'Model Name':model_name,
                  'Train Score': root_mean_squared_error(y_train,model.predict(X_train)),
                  'Test Score': root_mean_squared_error(y, model.predict(X))}
    score_df=pd.DataFrame(score_dict,columns=['Model Name','Train Score','Test Score'],index=range(1))
    if test_df is None:
        pass
    else:
       score_df = pd.concat([test_df,score_df])
       score_df.index = range(len(score_df))
       score_df.sort_values(by='Test Score')
    return score_df
    

# Predict on the test
test_scores = test_metrics(lasso_best,'Lasso',X_test,y_test)
test_scores
# Out:
#   Model Name  Train Score  Test Score
# 0      Lasso     0.776039    0.763157

# %% [markdown]
# ### Ridge
#
# Now we can assess the Ridge model in comparison to Lasso to see which type of regularization is best for our problem.

# %%
# Replace in pipeline

ridge_pipe = lr_pipe.set_params(model=Ridge())
ridge_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('subpipe_num',
#                                                   Pipeline(steps=[('num_impute',
#                                                                    SimpleImputer()),
#                                                                   ('ss',
#                                                                    StandardScaler())]),
#                                                   [3, 4, 5]),
#                                                  ('subpipe_cat',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   [0, 1, 2])])),
#                 ('model', Ridge())])

# %%
# Define your parameter grid
params = {
    'model__alpha':[.0001,.001,.01,1,10,100,1000],
    'model__solver': ['auto','svd','cholesky','lsqr','sag'],
    'model__tol': [1e-5,1e-3,1e-2,1e-1]
    
    
}
rcv=RandomizedSearchCV(ridge_pipe,param_distributions=params,scoring='neg_root_mean_squared_error',
                 return_train_score=True,cv=5,random_state=42,n_iter=15)

rcv.fit(X_train,y_train)
rcv.best_params_
# Out:
# {'model__tol': 0.001, 'model__solver': 'auto', 'model__alpha': 10}

# %% [markdown]
# Our Ridge model did so much better than the Lasso on the validation scores and around the same on our test, It is definitely the stronger of the two models

# %%
# Get train and test metrics
train_scores, ridge_best = rcv_metrics(rcv,'Ridge',X_train,y_train,train_scores)
display(train_scores)

test_scores = test_metrics(ridge_best,'Ridge',X_test,y_test,test_scores)
display(test_scores)
# Out:
#   Model Name  Val Train Score  Val Test Score
# 0      Lasso         1.382408        1.382881
# 1      Ridge         0.776968        0.777689
#   Model Name  Train Score  Test Score
# 0      Lasso     0.776039    0.763157
# 1      Ridge     0.776040    0.763174

# %% [markdown]
# ### `SMOTE` for Class Imbalance
#
# Since we know we have a class imbalance, lets see how our model does if we incorporate `SMOTE` and balance out our target class, making sure to only resample all classes but the majority.

# %%
# Create new pipe with `SMOTE` and the a logisitic model with best parameters found with RandomizedCV

imb_pipe = ImPipeline(steps=[('ct',CT),
                            ('sm',SMOTE(random_state=42,sampling_strategy='not majority')),
                            ('model', Ridge())])

# Define new parameter grid
params = {
    'model__alpha':[.0001,.001,.01,1,10,100,1000],
    'model__solver': ['auto','svd','cholesky','lsqr','sag'],
    'model__tol': [1e-5,1e-3,1e-2,1e-1]
    
    
}
rcv=RandomizedSearchCV(imb_pipe,param_distributions=params,scoring='neg_root_mean_squared_error',
                 return_train_score=True,cv=5,random_state=42,n_iter=15)

rcv.fit(X_train,y_train)
rcv.best_params_
# Out:
# {'model__tol': 0.1, 'model__solver': 'sag', 'model__alpha': 100}

# %% [markdown]
# Looks like `SMOTE` increased our scores substantially! We will leave smote out of the pipeline going forward.

# %%
# Get train and test metrics
train_scores, ridge_sm = rcv_metrics(rcv,'Ridge Sm',X_train,y_train,train_scores)
display(train_scores)

test_scores = test_metrics(ridge_sm,'Ridge Sm',X_test,y_test,test_scores)
display(test_scores)
# Out:
#   Model Name  Val Train Score  Val Test Score
# 0      Lasso         1.382408        1.382881
# 1      Ridge         0.776968        0.777689
# 2   Ridge Sm         0.840484        0.842000
#   Model Name  Train Score  Test Score
# 0      Lasso     0.776039    0.763157
# 1      Ridge     0.776040    0.763174
# 2   Ridge Sm     0.840221    0.828695

# %% [markdown]
# ## 6. DecisionTree Regressors
#
# Let's see if Decision Tree regressors can improve our scores

# %% [markdown]
# ### Decision Tree
#
# Next we will try a simple Decision Tree to see if the bagging and subspace sampling can get us a more stable score between model and cross validation.

# %%
# Replace in pipeline

dec_pipe = ridge_pipe.set_params(model=DecisionTreeRegressor(random_state=42))
dec_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('subpipe_num',
#                                                   Pipeline(steps=[('num_impute',
#                                                                    SimpleImputer()),
#                                                                   ('ss',
#                                                                    StandardScaler())]),
#                                                   [3, 4, 5]),
#                                                  ('subpipe_cat',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   [0, 1, 2])])),
#                 ('model', DecisionTreeRegressor(random_state=42))])

# %%
# Randomizedsearch CV 

params = {'model__criterion': ['squared_error', 'absolute_error','poisson'],
          'model__max_depth': [None, 10, 20, 30, 40],
          'model__min_samples_split': [2, 5, 10, 20],
          'model__splitter': ['best', 'random'],
          'model__min_samples_leaf': [1, 2, 5, 10]
}

rcv = RandomizedSearchCV(dec_pipe,param_distributions=params,scoring='neg_root_mean_squared_error',
                        return_train_score=True,random_state=42,n_iter=15)

rcv.fit(X_train,y_train)
rcv.best_params_
# Out:
# {'model__splitter': 'best',
#  'model__min_samples_split': 20,
#  'model__min_samples_leaf': 10,
#  'model__max_depth': 20,
#  'model__criterion': 'poisson'}

# %% [markdown]
# Looks like our Decision Tree did better than our Ridge but it is underfitting a bit, so hopefully the Random Forest and help address that.

# %%
# Get train and test metrics
train_scores, dec_best = rcv_metrics(rcv,'Decision',X_train,y_train,train_scores)
display(train_scores)

test_scores = test_metrics(dec_best,'Decision',X_test,y_test,test_scores)
display(test_scores)
# Out:
#   Model Name  Val Train Score  Val Test Score
# 0      Lasso         1.382408        1.382881
# 1      Ridge         0.776968        0.777689
# 2   Ridge Sm         0.840484        0.842000
# 3   Decision         0.629059        0.740311
#   Model Name  Train Score  Test Score
# 0      Lasso     0.776039    0.763157
# 1      Ridge     0.776040    0.763174
# 2   Ridge Sm     0.840221    0.828695
# 3   Decision     0.625636    0.688807

# %% [markdown]
# ### Random Forest
#
# Since Random Forests are better at addressing over/under fitting, we will try to see if we can improve our model with this ensemble model.

# %%
# Replace Regressor in pipeline

forest_pipe = ridge_pipe.set_params(model=RandomForestRegressor(random_state=42))
forest_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('subpipe_num',
#                                                   Pipeline(steps=[('num_impute',
#                                                                    SimpleImputer()),
#                                                                   ('ss',
#                                                                    StandardScaler())]),
#                                                   [3, 4, 5]),
#                                                  ('subpipe_cat',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   [0, 1, 2])])),
#                 ('model', RandomForestRegressor(random_state=42))])

# %% [markdown]
# It takes quite a bit to go through all the options available for some of these ensemble models so we will add a verbose of 3 for these to make sure that the code is running.

# %%
# Randomizedsearch CV 

params = {'model__criterion': ['squared_error', 'poisson'],
          'model__max_depth': [None, 10, 20, 30, 40],
          'model__min_samples_split': [2, 5, 10, 20],
          'model__warm_start': [True,False],
          'model__min_samples_leaf': [1, 2, 5, 10]
}

rcv = RandomizedSearchCV(forest_pipe,param_distributions=params,scoring='neg_root_mean_squared_error',
                        return_train_score=True,random_state=42,n_iter=15,verbose=3)

rcv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END model__criterion=poisson, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=20, model__warm_start=False;, score=(train=-0.609, test=-0.675) total time=   0.7s
# [CV 2/5] END model__criterion=poisson, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=20, model__warm_start=False;, score=(train=-0.610, test=-0.678) total time=   0.8s
# [CV 3/5] END model__criterion=poisson, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=20, model__warm_start=False;, score=(train=-0.613, test=-0.668) total time=   0.7s
# [CV 4/5] END model__criterion=poisson, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=20, model__warm_start=False;, score=(train=-0.607, test=-0.684) total time=   0.7s
# [CV 5/5] END model__criterion=poisson, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=20, model__warm_start=False;, score=(train=-0.613, test=-0.661) total time=   0.8s
# [CV 1/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=20, model__warm_start=True;, score=(train=-0.609, test=-0.675) total time=   0.7s
# [CV 2/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=20, model__warm_start=True;, score=(train=-0.610, test=-0.678) total time=   0.8s
# [CV 3/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=20, model__warm_start=True;, score=(train=-0.613, test=-0.668) total time=   0.8s
# [CV 4/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=20, model__warm_start=True;, score=(train=-0.607, test=-0.684) total time=   0.7s
# [CV 5/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=20, model__warm_start=True;, score=(train=-0.613, test=-0.661) total time=   0.8s
# [CV 1/5] END model__criterion=squared_error, model__max_depth=None, model__min_samples_leaf=10, model__min_samples_split=2, model__warm_start=False;, score=(train=-0.627, test=-0.673) total time=   0.7s
# [CV 2/5] END model__criterion=squared_error, model__max_depth=None, model__min_samples_leaf=10, model__min_samples_split=2, model__warm_start=False;, score=(train=-0.627, test=-0.678) total time=   0.6s
# [CV 3/5] END model__criterion=squared_error, model__max_depth=None, model__min_samples_leaf=10, model__min_samples_split=2, model__warm_start=False;, score=(train=-0.631, test=-0.670) total time=   0.7s
# [CV 4/5] END model__criterion=squared_error, model__max_depth=None, model__min_samples_leaf=10, model__min_samples_split=2, model__warm_start=False;, score=(train=-0.624, test=-0.689) total time=   0.6s
# [CV 5/5] END model__criterion=squared_error, model__max_depth=None, model__min_samples_leaf=10, model__min_samples_split=2, model__warm_start=False;, score=(train=-0.631, test=-0.663) total time=   0.6s
# [CV 1/5] END model__criterion=squared_error, model__max_depth=10, model__min_samples_leaf=10, model__min_samples_split=20, model__warm_start=False;, score=(train=-0.639, test=-0.672) total time=   0.6s
# [CV 2/5] END model__criterion=squared_error, model__max_depth=10, model__min_samples_leaf=10, model__min_samples_split=20, model__warm_start=False;, score=(train=-0.638, test=-0.675) total time=   0.6s
# [CV 3/5] END model__criterion=squared_error, model__max_depth=10, model__min_samples_leaf=10, model__min_samples_split=20, model__warm_start=False;, score=(train=-0.642, test=-0.668) total time=   0.6s
# [CV 4/5] END model__criterion=squared_error, model__max_depth=10, model__min_samples_leaf=10, model__min_samples_split=20, model__warm_start=False;, score=(train=-0.635, test=-0.690) total time=   0.6s
# [CV 5/5] END model__criterion=squared_error, model__max_depth=10, model__min_samples_leaf=10, model__min_samples_split=20, model__warm_start=False;, score=(train=-0.643, test=-0.661) total time=   0.6s
# [CV 1/5] END model__criterion=squared_error, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__warm_start=False;, score=(train=-0.560, test=-0.703) total time=   0.8s
# [CV 2/5] END model__criterion=squared_error, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__warm_start=False;, score=(train=-0.561, test=-0.706) total time=   0.8s
# [CV 3/5] END model__criterion=squared_error, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__warm_start=False;, score=(train=-0.565, test=-0.690) total time=   0.8s
# [CV 4/5] END model__criterion=squared_error, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__warm_start=False;, score=(train=-0.559, test=-0.711) total time=   0.8s
# [CV 5/5] END model__criterion=squared_error, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__warm_start=False;, score=(train=-0.565, test=-0.690) total time=   0.8s
# [CV 1/5] END model__criterion=squared_error, model__max_depth=30, model__min_samples_leaf=2, model__min_samples_split=20, model__warm_start=True;, score=(train=-0.610, test=-0.673) total time=   0.7s
# [CV 2/5] END model__criterion=squared_error, model__max_depth=30, model__min_samples_leaf=2, model__min_samples_split=20, model__warm_start=True;, score=(train=-0.610, test=-0.678) total time=   0.6s
# [CV 3/5] END model__criterion=squared_error, model__max_depth=30, model__min_samples_leaf=2, model__min_samples_split=20, model__warm_start=True;, score=(train=-0.614, test=-0.668) total time=   0.7s
# [CV 4/5] END model__criterion=squared_error, model__max_depth=30, model__min_samples_leaf=2, model__min_samples_split=20, model__warm_start=True;, score=(train=-0.608, test=-0.684) total time=   0.7s
# [CV 5/5] END model__criterion=squared_error, model__max_depth=30, model__min_samples_leaf=2, model__min_samples_split=20, model__warm_start=True;, score=(train=-0.614, test=-0.661) total time=   0.7s
# [CV 1/5] END model__criterion=poisson, model__max_depth=None, model__min_samples_leaf=10, model__min_samples_split=5, model__warm_start=True;, score=(train=-0.626, test=-0.674) total time=   0.8s
# [CV 2/5] END model__criterion=poisson, model__max_depth=None, model__min_samples_leaf=10, model__min_samples_split=5, model__warm_start=True;, score=(train=-0.626, test=-0.676) total time=   0.8s
# [CV 3/5] END model__criterion=poisson, model__max_depth=None, model__min_samples_leaf=10, model__min_samples_split=5, model__warm_start=True;, score=(train=-0.631, test=-0.672) total time=   0.7s
# [CV 4/5] END model__criterion=poisson, model__max_depth=None, model__min_samples_leaf=10, model__min_samples_split=5, model__warm_start=True;, score=(train=-0.624, test=-0.687) total time=   0.8s
# [CV 5/5] END model__criterion=poisson, model__max_depth=None, model__min_samples_leaf=10, model__min_samples_split=5, model__warm_start=True;, score=(train=-0.629, test=-0.661) total time=   0.7s
# [CV 1/5] END model__criterion=squared_error, model__max_depth=40, model__min_samples_leaf=2, model__min_samples_split=20, model__warm_start=False;, score=(train=-0.610, test=-0.673) total time=   0.7s
# [CV 2/5] END model__criterion=squared_error, model__max_depth=40, model__min_samples_leaf=2, model__min_samples_split=20, model__warm_start=False;, score=(train=-0.610, test=-0.678) total time=   0.7s
# [CV 3/5] END model__criterion=squared_error, model__max_depth=40, model__min_samples_leaf=2, model__min_samples_split=20, model__warm_start=False;, score=(train=-0.614, test=-0.668) total time=   0.7s
# [CV 4/5] END model__criterion=squared_error, model__max_depth=40, model__min_samples_leaf=2, model__min_samples_split=20, model__warm_start=False;, score=(train=-0.608, test=-0.684) total time=   0.7s
# [CV 5/5] END model__criterion=squared_error, model__max_depth=40, model__min_samples_leaf=2, model__min_samples_split=20, model__warm_start=False;, score=(train=-0.614, test=-0.661) total time=   0.7s
# [CV 1/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=5, model__min_samples_split=10, model__warm_start=True;, score=(train=-0.599, test=-0.682) total time=   0.8s
# [CV 2/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=5, model__min_samples_split=10, model__warm_start=True;, score=(train=-0.600, test=-0.682) total time=   0.8s
# [CV 3/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=5, model__min_samples_split=10, model__warm_start=True;, score=(train=-0.605, test=-0.672) total time=   0.8s
# [CV 4/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=5, model__min_samples_split=10, model__warm_start=True;, score=(train=-0.598, test=-0.692) total time=   0.8s
# [CV 5/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=5, model__min_samples_split=10, model__warm_start=True;, score=(train=-0.603, test=-0.669) total time=   0.8s
# [CV 1/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__warm_start=True;, score=(train=-0.534, test=-0.726) total time=   1.0s
# [CV 2/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__warm_start=True;, score=(train=-0.535, test=-0.733) total time=   0.9s
# [CV 3/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__warm_start=True;, score=(train=-0.539, test=-0.710) total time=   1.0s
# [CV 4/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__warm_start=True;, score=(train=-0.534, test=-0.735) total time=   1.0s
# [CV 5/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__warm_start=True;, score=(train=-0.539, test=-0.714) total time=   0.9s
# [CV 1/5] END model__criterion=squared_error, model__max_depth=20, model__min_samples_leaf=10, model__min_samples_split=5, model__warm_start=True;, score=(train=-0.627, test=-0.673) total time=   0.7s
# [CV 2/5] END model__criterion=squared_error, model__max_depth=20, model__min_samples_leaf=10, model__min_samples_split=5, model__warm_start=True;, score=(train=-0.627, test=-0.678) total time=   0.6s
# [CV 3/5] END model__criterion=squared_error, model__max_depth=20, model__min_samples_leaf=10, model__min_samples_split=5, model__warm_start=True;, score=(train=-0.631, test=-0.670) total time=   0.7s
# [CV 4/5] END model__criterion=squared_error, model__max_depth=20, model__min_samples_leaf=10, model__min_samples_split=5, model__warm_start=True;, score=(train=-0.624, test=-0.689) total time=   0.7s
# [CV 5/5] END model__criterion=squared_error, model__max_depth=20, model__min_samples_leaf=10, model__min_samples_split=5, model__warm_start=True;, score=(train=-0.631, test=-0.663) total time=   0.6s
# [CV 1/5] END model__criterion=squared_error, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=10, model__warm_start=True;, score=(train=-0.584, test=-0.686) total time=   0.7s
# [CV 2/5] END model__criterion=squared_error, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=10, model__warm_start=True;, score=(train=-0.585, test=-0.689) total time=   0.7s
# [CV 3/5] END model__criterion=squared_error, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=10, model__warm_start=True;, score=(train=-0.589, test=-0.676) total time=   0.7s
# [CV 4/5] END model__criterion=squared_error, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=10, model__warm_start=True;, score=(train=-0.582, test=-0.695) total time=   0.7s
# [CV 5/5] END model__criterion=squared_error, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=10, model__warm_start=True;, score=(train=-0.588, test=-0.675) total time=   0.7s
# [CV 1/5] END model__criterion=squared_error, model__max_depth=20, model__min_samples_leaf=5, model__min_samples_split=5, model__warm_start=True;, score=(train=-0.600, test=-0.680) total time=   0.7s
# [CV 2/5] END model__criterion=squared_error, model__max_depth=20, model__min_samples_leaf=5, model__min_samples_split=5, model__warm_start=True;, score=(train=-0.600, test=-0.683) total time=   0.7s
# [CV 3/5] END model__criterion=squared_error, model__max_depth=20, model__min_samples_leaf=5, model__min_samples_split=5, model__warm_start=True;, score=(train=-0.605, test=-0.672) total time=   0.7s
# [CV 4/5] END model__criterion=squared_error, model__max_depth=20, model__min_samples_leaf=5, model__min_samples_split=5, model__warm_start=True;, score=(train=-0.598, test=-0.693) total time=   0.7s
# [CV 5/5] END model__criterion=squared_error, model__max_depth=20, model__min_samples_leaf=5, model__min_samples_split=5, model__warm_start=True;, score=(train=-0.604, test=-0.670) total time=   0.7s
# [CV 1/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=5, model__min_samples_split=2, model__warm_start=True;, score=(train=-0.599, test=-0.682) total time=   0.8s
# [CV 2/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=5, model__min_samples_split=2, model__warm_start=True;, score=(train=-0.600, test=-0.682) total time=   0.8s
# [CV 3/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=5, model__min_samples_split=2, model__warm_start=True;, score=(train=-0.605, test=-0.672) total time=   0.8s
# [CV 4/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=5, model__min_samples_split=2, model__warm_start=True;, score=(train=-0.598, test=-0.692) total time=   0.8s
# [CV 5/5] END model__criterion=poisson, model__max_depth=20, model__min_samples_leaf=5, model__min_samples_split=2, model__warm_start=True;, score=(train=-0.603, test=-0.669) total time=   0.8s
# [CV 1/5] END model__criterion=poisson, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=10, model__warm_start=True;, score=(train=-0.584, test=-0.689) total time=   0.8s
# [CV 2/5] END model__criterion=poisson, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=10, model__warm_start=True;, score=(train=-0.585, test=-0.688) total time=   0.8s
# [CV 3/5] END model__criterion=poisson, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=10, model__warm_start=True;, score=(train=-0.589, test=-0.676) total time=   0.8s
# [CV 4/5] END model__criterion=poisson, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=10, model__warm_start=True;, score=(train=-0.583, test=-0.695) total time=   0.8s
# [CV 5/5] END model__criterion=poisson, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=10, model__warm_start=True;, score=(train=-0.588, test=-0.674) total time=   0.8s
# RandomizedSearchCV(estimator=Pipeline(steps=[('ct',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('subpipe_num',
#                                                                                Pipeline(steps=[('num_impute',
#                                                                                                 SimpleImputer()),
#                                                                                                ('ss',
#                                                                                                 StandardScaler())]),
#                                                                                [3,
#                                                                                 4,
#                                                                                 5]),
#                                                                               ('subpipe_cat',
#                                                                                Pipeline(steps=[('ohe',
#                                                                                                 OneHotEncoder(handle_unknown='ignore',
#                                                                                                               sparse_output=False))]),
#                                                                                [0,
#                                                                                 1,
#                                                                                 2])])),
#                                              ('model',
#                                               RandomForestRegressor(random_state=42))]),
#                    n_iter=15,
#                    param_distributions={'model__criterion': ['squared_error',
#                                                              'poisson'],
#                                         'model__max_depth': [None, 10, 20, 30,
#                                                              40],
#                                         'model__min_samples_leaf': [1, 2, 5,
#                                                                     10],
#                                         'model__min_samples_split': [2, 5, 10,
#                                                                      20],
#                                         'model__warm_start': [True, False]},
#                    random_state=42, return_train_score=True,
#                    scoring='neg_root_mean_squared_error', verbose=3)

# %%
rcv.best_params_
# Out:
# {'model__warm_start': True,
#  'model__min_samples_split': 20,
#  'model__min_samples_leaf': 2,
#  'model__max_depth': 30,
#  'model__criterion': 'squared_error'}

# %% [markdown]
# The Random Forest did even better than our Decision Tree on the validation data and test daya. However, it is still underfitting a bit. Lastly we will try some boosting models.

# %%
# Get train and test metrics
train_scores, forest_best = rcv_metrics(rcv,'Forest',X_train,y_train,train_scores)
display(train_scores)

test_scores = test_metrics(forest_best,'Forest',X_test,y_test,test_scores)
display(test_scores)
# Out:
#   Model Name  Val Train Score  Val Test Score
# 0      Lasso         1.382408        1.382881
# 1      Ridge         0.776968        0.777689
# 2   Ridge Sm         0.840484        0.842000
# 3   Decision         0.629059        0.740311
# 4     Forest         0.602695        0.681237
#   Model Name  Train Score  Test Score
# 0      Lasso     0.776039    0.763157
# 1      Ridge     0.776040    0.763174
# 2   Ridge Sm     0.840221    0.828695
# 3   Decision     0.625636    0.688807
# 4     Forest     0.613752    0.674664

# %% [markdown]
# ## 7. Boosting Regressors
#
# Lets see boosting Regressors yeild better results, starting with `GradientRegressor` first.

# %% [markdown]
# ### GradientBoost

# %%
# Replace in pipeline

gradient_pipe = ridge_pipe.set_params(model=GradientBoostingRegressor(random_state=42))
gradient_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('subpipe_num',
#                                                   Pipeline(steps=[('num_impute',
#                                                                    SimpleImputer()),
#                                                                   ('ss',
#                                                                    StandardScaler())]),
#                                                   [3, 4, 5]),
#                                                  ('subpipe_cat',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   [0, 1, 2])])),
#                 ('model', GradientBoostingRegressor(random_state=42))])

# %% [markdown]
# We will set verbose to 3 so that we can confirm the code is running as this CV takes a bit for the boosting algorithms to run when there are this many hyperparameters to tune.

# %%
# Randomizedsearch CV 

params_gb = {'model__max_depth': [3, 5, 10, None],
          'model__learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3],
          'model__n_estimators': [50, 100, 200, 300, 400],
          'model__min_samples_split':  [2, 5, 10, 20],
          'model__max_features': ['sqrt','log2',None],
          'model__subsample': [0.5, 0.75, 1.0],
          'model__min_samples_leaf': [1, 2, 5, 10]
          
}

rcv_gb = RandomizedSearchCV(gradient_pipe,param_distributions=params_gb,scoring='neg_root_mean_squared_error',
                        return_train_score=True,random_state=42,n_iter=18,verbose=3)

rcv_gb.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END model__learning_rate=0.1, model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300, model__subsample=0.75;, score=(train=-0.530, test=-0.745) total time=   1.2s
# [CV 2/5] END model__learning_rate=0.1, model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300, model__subsample=0.75;, score=(train=-0.531, test=-0.757) total time=   1.2s
# [CV 3/5] END model__learning_rate=0.1, model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300, model__subsample=0.75;, score=(train=-0.535, test=-0.731) total time=   1.2s
# [CV 4/5] END model__learning_rate=0.1, model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300, model__subsample=0.75;, score=(train=-0.529, test=-0.755) total time=   1.2s
# [CV 5/5] END model__learning_rate=0.1, model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300, model__subsample=0.75;, score=(train=-0.534, test=-0.736) total time=   1.2s
# [CV 1/5] END model__learning_rate=0.01, model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=5, model__n_estimators=100, model__subsample=1.0;, score=(train=-1.055, test=-1.039) total time=   0.3s
# [CV 2/5] END model__learning_rate=0.01, model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=5, model__n_estimators=100, model__subsample=1.0;, score=(train=-1.051, test=-1.056) total time=   0.3s
# [CV 3/5] END model__learning_rate=0.01, model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=5, model__n_estimators=100, model__subsample=1.0;, score=(train=-1.054, test=-1.059) total time=   0.3s
# [CV 4/5] END model__learning_rate=0.01, model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=5, model__n_estimators=100, model__subsample=1.0;, score=(train=-1.050, test=-1.080) total time=   0.3s
# [CV 5/5] END model__learning_rate=0.01, model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=5, model__n_estimators=100, model__subsample=1.0;, score=(train=-1.053, test=-1.057) total time=   0.3s
# [CV 1/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=20, model__n_estimators=100, model__subsample=1.0;, score=(train=-0.546, test=-0.717) total time=   0.6s
# [CV 2/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=20, model__n_estimators=100, model__subsample=1.0;, score=(train=-0.546, test=-0.726) total time=   0.6s
# [CV 3/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=20, model__n_estimators=100, model__subsample=1.0;, score=(train=-0.550, test=-0.706) total time=   0.6s
# [CV 4/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=20, model__n_estimators=100, model__subsample=1.0;, score=(train=-0.545, test=-0.728) total time=   0.6s
# [CV 5/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=20, model__n_estimators=100, model__subsample=1.0;, score=(train=-0.550, test=-0.707) total time=   0.6s
# [CV 1/5] END model__learning_rate=0.3, model__max_depth=10, model__max_features=log2, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=200, model__subsample=1.0;, score=(train=-0.553, test=-0.718) total time=   0.9s
# [CV 2/5] END model__learning_rate=0.3, model__max_depth=10, model__max_features=log2, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=200, model__subsample=1.0;, score=(train=-0.554, test=-0.719) total time=   0.9s
# [CV 3/5] END model__learning_rate=0.3, model__max_depth=10, model__max_features=log2, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=200, model__subsample=1.0;, score=(train=-0.559, test=-0.706) total time=   0.9s
# [CV 4/5] END model__learning_rate=0.3, model__max_depth=10, model__max_features=log2, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=200, model__subsample=1.0;, score=(train=-0.555, test=-0.723) total time=   0.9s
# [CV 5/5] END model__learning_rate=0.3, model__max_depth=10, model__max_features=log2, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=200, model__subsample=1.0;, score=(train=-0.559, test=-0.705) total time=   0.9s
# [CV 1/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=50, model__subsample=0.75;, score=(train=-0.600, test=-0.702) total time=   0.2s
# [CV 2/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=50, model__subsample=0.75;, score=(train=-0.600, test=-0.710) total time=   0.2s
# [CV 3/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=50, model__subsample=0.75;, score=(train=-0.604, test=-0.697) total time=   0.2s
# [CV 4/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=50, model__subsample=0.75;, score=(train=-0.598, test=-0.720) total time=   0.2s
# [CV 5/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=50, model__subsample=0.75;, score=(train=-0.603, test=-0.697) total time=   0.2s
# [CV 1/5] END model__learning_rate=0.3, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=10, model__min_samples_split=5, model__n_estimators=300, model__subsample=0.5;, score=(train=-0.656, test=-0.672) total time=   0.4s
# [CV 2/5] END model__learning_rate=0.3, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=10, model__min_samples_split=5, model__n_estimators=300, model__subsample=0.5;, score=(train=-0.657, test=-0.675) total time=   0.5s
# [CV 3/5] END model__learning_rate=0.3, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=10, model__min_samples_split=5, model__n_estimators=300, model__subsample=0.5;, score=(train=-0.659, test=-0.669) total time=   0.4s
# [CV 4/5] END model__learning_rate=0.3, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=10, model__min_samples_split=5, model__n_estimators=300, model__subsample=0.5;, score=(train=-0.653, test=-0.696) total time=   0.4s
# [CV 5/5] END model__learning_rate=0.3, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=10, model__min_samples_split=5, model__n_estimators=300, model__subsample=0.5;, score=(train=-0.658, test=-0.665) total time=   0.4s
# [CV 1/5] END model__learning_rate=0.2, model__max_depth=None, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, model__subsample=0.75;, score=(train=-0.526, test=-0.779) total time=   1.2s
# [CV 2/5] END model__learning_rate=0.2, model__max_depth=None, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, model__subsample=0.75;, score=(train=-0.526, test=-0.795) total time=   1.2s
# [CV 3/5] END model__learning_rate=0.2, model__max_depth=None, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, model__subsample=0.75;, score=(train=-0.531, test=-0.756) total time=   1.2s
# [CV 4/5] END model__learning_rate=0.2, model__max_depth=None, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, model__subsample=0.75;, score=(train=-0.526, test=-0.793) total time=   1.2s
# [CV 5/5] END model__learning_rate=0.2, model__max_depth=None, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, model__subsample=0.75;, score=(train=-0.530, test=-0.769) total time=   1.2s
# [CV 1/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=None, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=100, model__subsample=0.75;, score=(train=-0.576, test=-0.694) total time=   1.0s
# [CV 2/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=None, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=100, model__subsample=0.75;, score=(train=-0.577, test=-0.700) total time=   0.9s
# [CV 3/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=None, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=100, model__subsample=0.75;, score=(train=-0.581, test=-0.681) total time=   0.9s
# [CV 4/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=None, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=100, model__subsample=0.75;, score=(train=-0.576, test=-0.705) total time=   0.9s
# [CV 5/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=None, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=100, model__subsample=0.75;, score=(train=-0.581, test=-0.682) total time=   0.9s
# [CV 1/5] END model__learning_rate=0.1, model__max_depth=3, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300, model__subsample=0.75;, score=(train=-0.653, test=-0.662) total time=   1.0s
# [CV 2/5] END model__learning_rate=0.1, model__max_depth=3, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300, model__subsample=0.75;, score=(train=-0.652, test=-0.665) total time=   1.0s
# [CV 3/5] END model__learning_rate=0.1, model__max_depth=3, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300, model__subsample=0.75;, score=(train=-0.652, test=-0.662) total time=   1.0s
# [CV 4/5] END model__learning_rate=0.1, model__max_depth=3, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300, model__subsample=0.75;, score=(train=-0.648, test=-0.683) total time=   1.0s
# [CV 5/5] END model__learning_rate=0.1, model__max_depth=3, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300, model__subsample=0.75;, score=(train=-0.653, test=-0.660) total time=   1.0s
# [CV 1/5] END model__learning_rate=0.01, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=10, model__min_samples_split=20, model__n_estimators=50, model__subsample=0.75;, score=(train=-1.497, test=-1.474) total time=   0.1s
# [CV 2/5] END model__learning_rate=0.01, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=10, model__min_samples_split=20, model__n_estimators=50, model__subsample=0.75;, score=(train=-1.492, test=-1.491) total time=   0.1s
# [CV 3/5] END model__learning_rate=0.01, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=10, model__min_samples_split=20, model__n_estimators=50, model__subsample=0.75;, score=(train=-1.490, test=-1.492) total time=   0.1s
# [CV 4/5] END model__learning_rate=0.01, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=10, model__min_samples_split=20, model__n_estimators=50, model__subsample=0.75;, score=(train=-1.487, test=-1.512) total time=   0.1s
# [CV 5/5] END model__learning_rate=0.01, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=10, model__min_samples_split=20, model__n_estimators=50, model__subsample=0.75;, score=(train=-1.494, test=-1.498) total time=   0.1s
# [CV 1/5] END model__learning_rate=0.3, model__max_depth=10, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300, model__subsample=1.0;, score=(train=-0.522, test=-0.765) total time=   3.2s
# [CV 2/5] END model__learning_rate=0.3, model__max_depth=10, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300, model__subsample=1.0;, score=(train=-0.523, test=-0.784) total time=   3.2s
# [CV 3/5] END model__learning_rate=0.3, model__max_depth=10, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300, model__subsample=1.0;, score=(train=-0.527, test=-0.749) total time=   3.2s
# [CV 4/5] END model__learning_rate=0.3, model__max_depth=10, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300, model__subsample=1.0;, score=(train=-0.522, test=-0.779) total time=   3.2s
# [CV 5/5] END model__learning_rate=0.3, model__max_depth=10, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300, model__subsample=1.0;, score=(train=-0.526, test=-0.757) total time=   3.2s
# [CV 1/5] END model__learning_rate=0.05, model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=20, model__n_estimators=50, model__subsample=0.75;, score=(train=-0.630, test=-0.686) total time=   0.2s
# [CV 2/5] END model__learning_rate=0.05, model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=20, model__n_estimators=50, model__subsample=0.75;, score=(train=-0.632, test=-0.694) total time=   0.2s
# [CV 3/5] END model__learning_rate=0.05, model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=20, model__n_estimators=50, model__subsample=0.75;, score=(train=-0.633, test=-0.682) total time=   0.2s
# [CV 4/5] END model__learning_rate=0.05, model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=20, model__n_estimators=50, model__subsample=0.75;, score=(train=-0.627, test=-0.708) total time=   0.2s
# [CV 5/5] END model__learning_rate=0.05, model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=20, model__n_estimators=50, model__subsample=0.75;, score=(train=-0.632, test=-0.684) total time=   0.2s
# [CV 1/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=20, model__n_estimators=400, model__subsample=0.75;, score=(train=-0.527, test=-0.756) total time=   4.0s
# [CV 2/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=20, model__n_estimators=400, model__subsample=0.75;, score=(train=-0.527, test=-0.766) total time=   3.9s
# [CV 3/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=20, model__n_estimators=400, model__subsample=0.75;, score=(train=-0.532, test=-0.732) total time=   3.9s
# [CV 4/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=20, model__n_estimators=400, model__subsample=0.75;, score=(train=-0.526, test=-0.760) total time=   3.8s
# [CV 5/5] END model__learning_rate=0.05, model__max_depth=None, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=20, model__n_estimators=400, model__subsample=0.75;, score=(train=-0.531, test=-0.743) total time=   3.9s
# [CV 1/5] END model__learning_rate=0.3, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=20, model__n_estimators=300, model__subsample=1.0;, score=(train=-0.651, test=-0.668) total time=   0.5s
# [CV 2/5] END model__learning_rate=0.3, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=20, model__n_estimators=300, model__subsample=1.0;, score=(train=-0.650, test=-0.670) total time=   0.5s
# [CV 3/5] END model__learning_rate=0.3, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=20, model__n_estimators=300, model__subsample=1.0;, score=(train=-0.652, test=-0.665) total time=   0.5s
# [CV 4/5] END model__learning_rate=0.3, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=20, model__n_estimators=300, model__subsample=1.0;, score=(train=-0.647, test=-0.685) total time=   0.5s
# [CV 5/5] END model__learning_rate=0.3, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=20, model__n_estimators=300, model__subsample=1.0;, score=(train=-0.652, test=-0.661) total time=   0.5s
# [CV 1/5] END model__learning_rate=0.2, model__max_depth=None, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200, model__subsample=1.0;, score=(train=-0.521, test=-0.766) total time=   4.5s
# [CV 2/5] END model__learning_rate=0.2, model__max_depth=None, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200, model__subsample=1.0;, score=(train=-0.522, test=-0.784) total time=   3.7s
# [CV 3/5] END model__learning_rate=0.2, model__max_depth=None, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200, model__subsample=1.0;, score=(train=-0.526, test=-0.751) total time=   3.7s
# [CV 4/5] END model__learning_rate=0.2, model__max_depth=None, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200, model__subsample=1.0;, score=(train=-0.521, test=-0.782) total time=   4.2s
# [CV 5/5] END model__learning_rate=0.2, model__max_depth=None, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200, model__subsample=1.0;, score=(train=-0.526, test=-0.758) total time=   3.9s
# [CV 1/5] END model__learning_rate=0.2, model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300, model__subsample=1.0;, score=(train=-0.521, test=-0.763) total time=   2.7s
# [CV 2/5] END model__learning_rate=0.2, model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300, model__subsample=1.0;, score=(train=-0.522, test=-0.785) total time=   2.6s
# [CV 3/5] END model__learning_rate=0.2, model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300, model__subsample=1.0;, score=(train=-0.526, test=-0.752) total time=   2.7s
# [CV 4/5] END model__learning_rate=0.2, model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300, model__subsample=1.0;, score=(train=-0.521, test=-0.777) total time=   2.7s
# [CV 5/5] END model__learning_rate=0.2, model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300, model__subsample=1.0;, score=(train=-0.526, test=-0.760) total time=   2.7s
# [CV 1/5] END model__learning_rate=0.1, model__max_depth=None, model__max_features=log2, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=400, model__subsample=0.5;, score=(train=-0.534, test=-0.752) total time=   1.6s
# [CV 2/5] END model__learning_rate=0.1, model__max_depth=None, model__max_features=log2, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=400, model__subsample=0.5;, score=(train=-0.534, test=-0.766) total time=   1.6s
# [CV 3/5] END model__learning_rate=0.1, model__max_depth=None, model__max_features=log2, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=400, model__subsample=0.5;, score=(train=-0.539, test=-0.734) total time=   1.6s
# [CV 4/5] END model__learning_rate=0.1, model__max_depth=None, model__max_features=log2, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=400, model__subsample=0.5;, score=(train=-0.534, test=-0.762) total time=   1.6s
# [CV 5/5] END model__learning_rate=0.1, model__max_depth=None, model__max_features=log2, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=400, model__subsample=0.5;, score=(train=-0.538, test=-0.740) total time=   1.6s
# [CV 1/5] END model__learning_rate=0.01, model__max_depth=10, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, model__subsample=1.0;, score=(train=-0.940, test=-0.958) total time=   0.5s
# [CV 2/5] END model__learning_rate=0.01, model__max_depth=10, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, model__subsample=1.0;, score=(train=-0.939, test=-0.980) total time=   0.5s
# [CV 3/5] END model__learning_rate=0.01, model__max_depth=10, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, model__subsample=1.0;, score=(train=-0.940, test=-0.967) total time=   0.5s
# [CV 4/5] END model__learning_rate=0.01, model__max_depth=10, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, model__subsample=1.0;, score=(train=-0.936, test=-0.991) total time=   0.5s
# [CV 5/5] END model__learning_rate=0.01, model__max_depth=10, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, model__subsample=1.0;, score=(train=-0.939, test=-0.974) total time=   0.5s
# RandomizedSearchCV(estimator=Pipeline(steps=[('ct',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('subpipe_num',
#                                                                                Pipeline(steps=[('num_impute',
#                                                                                                 SimpleImputer()),
#                                                                                                ('ss',
#                                                                                                 StandardScaler())]),
#                                                                                [3,
#                                                                                 4,
#                                                                                 5]),
#                                                                               ('subpipe_cat',
#                                                                                Pipeline(steps=[('ohe',
#                                                                                                 OneHotEncoder(handle_unknown='ignore',
#                                                                                                               sparse_output=False))]),
#                                                                                [0,
#                                                                                 1,
#                                                                                 2])])),
#                                              ('model',
#                                               GradientBoostingRegressor...
#                    param_distributions={'model__learning_rate': [0.01, 0.05,
#                                                                  0.1, 0.2,
#                                                                  0.3],
#                                         'model__max_depth': [3, 5, 10, None],
#                                         'model__max_features': ['sqrt', 'log2',
#                                                                 None],
#                                         'model__min_samples_leaf': [1, 2, 5,
#                                                                     10],
#                                         'model__min_samples_split': [2, 5, 10,
#                                                                      20],
#                                         'model__n_estimators': [50, 100, 200,
#                                                                 300, 400],
#                                         'model__subsample': [0.5, 0.75, 1.0]},
#                    random_state=42, return_train_score=True,
#                    scoring='neg_root_mean_squared_error', verbose=3)

# %%
# Print parameters of best estimate
rcv_gb.best_params_
# Out:
# {'model__subsample': 0.75,
#  'model__n_estimators': 300,
#  'model__min_samples_split': 5,
#  'model__min_samples_leaf': 1,
#  'model__max_features': None,
#  'model__max_depth': 3,
#  'model__learning_rate': 0.1}

# %% [markdown]
# Our Gradient Boost is underfitting on the validation data but not so much on the train/test data.

# %%
# Get train and test metrics
train_scores, gradient_best = rcv_metrics(rcv_gb,'GradientBoost',X_train,y_train,train_scores)
display(train_scores)

test_scores = test_metrics(gradient_best,'GradientBoost',X_test,y_test,test_scores)
display(test_scores)
# Out:
#       Model Name  Val Train Score  Val Test Score
# 0          Lasso         1.382408        1.382881
# 1          Ridge         0.776968        0.777689
# 2       Ridge Sm         0.840484        0.842000
# 3       Decision         0.629059        0.740311
# 4         Forest         0.602695        0.681237
# 5  GradientBoost         0.669444        0.799089
#       Model Name  Train Score  Test Score
# 0          Lasso     0.776039    0.763157
# 1          Ridge     0.776040    0.763174
# 2       Ridge Sm     0.840221    0.828695
# 3       Decision     0.625636    0.688807
# 4         Forest     0.613752    0.674664
# 5  GradientBoost     0.653514    0.663821

# %% [markdown]
# ### XGBoost

# %%
# Replace Regressor in pipeline

xgboost_pipe = ridge_pipe.set_params(model=XGBRegressor(random_state=42))
xgboost_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('subpipe_num',
#                                                   Pipeline(steps=[('num_impute',
#                                                                    SimpleImputer()),
#                                                                   ('ss',
#                                                                    StandardScaler())]),
#                                                   [3, 4, 5]),
#                                                  ('subpipe_cat',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   [0, 1, 2])])),
#                 ('model',
#                  XGBRegressor(base_score=None, booster=None, callbacks=No...
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=None, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=None, n_jobs=None,
#                               num_parallel_tree=None, random_state=42, ...))])

# %%
# Randomizedsearch CV 

params_xgb = {'model__learning_rate':  [0.01, 0.05, 0.1, 0.3, 0.5],
          'model__n_estimators': [50, 100, 200, 300, 400],
          'model__min_child_weight':  [3, 5, 7, 9, 11],
          'model__colsample_bytree': [0.5, 0.75, 1.0],
          'model__subsample': [0.5, 0.75, 1.0],
          'model__reg_alpha':  [0, 0.1, 0.5, 1.0],
          'model__reg_lambda':  [0, 0.1, 0.5, 1.0],
          'model__max_depth': [3, 5, 7, 9, 11]
}

rcv_xgb = RandomizedSearchCV(xgboost_pipe,param_distributions=params_xgb,scoring='neg_root_mean_squared_error',
                        return_train_score=True,random_state=42,n_iter=12,verbose=3)

rcv_xgb.fit(X_train,y_train)
rcv_xgb.best_params_
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END model__colsample_bytree=0.5, model__learning_rate=0.1, model__max_depth=9, model__min_child_weight=3, model__n_estimators=400, model__reg_alpha=0, model__reg_lambda=0.1, model__subsample=0.5;, score=(train=-0.590, test=-0.693) total time=   0.6s
# [CV 2/5] END model__colsample_bytree=0.5, model__learning_rate=0.1, model__max_depth=9, model__min_child_weight=3, model__n_estimators=400, model__reg_alpha=0, model__reg_lambda=0.1, model__subsample=0.5;, score=(train=-0.592, test=-0.696) total time=   0.5s
# [CV 3/5] END model__colsample_bytree=0.5, model__learning_rate=0.1, model__max_depth=9, model__min_child_weight=3, model__n_estimators=400, model__reg_alpha=0, model__reg_lambda=0.1, model__subsample=0.5;, score=(train=-0.597, test=-0.680) total time=   0.5s
# [CV 4/5] END model__colsample_bytree=0.5, model__learning_rate=0.1, model__max_depth=9, model__min_child_weight=3, model__n_estimators=400, model__reg_alpha=0, model__reg_lambda=0.1, model__subsample=0.5;, score=(train=-0.591, test=-0.705) total time=   0.6s
# [CV 5/5] END model__colsample_bytree=0.5, model__learning_rate=0.1, model__max_depth=9, model__min_child_weight=3, model__n_estimators=400, model__reg_alpha=0, model__reg_lambda=0.1, model__subsample=0.5;, score=(train=-0.595, test=-0.689) total time=   0.5s
# [CV 1/5] END model__colsample_bytree=0.5, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=9, model__n_estimators=200, model__reg_alpha=1.0, model__reg_lambda=0.5, model__subsample=1.0;, score=(train=-0.865, test=-0.846) total time=   0.1s
# [CV 2/5] END model__colsample_bytree=0.5, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=9, model__n_estimators=200, model__reg_alpha=1.0, model__reg_lambda=0.5, model__subsample=1.0;, score=(train=-0.861, test=-0.864) total time=   0.1s
# [CV 3/5] END model__colsample_bytree=0.5, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=9, model__n_estimators=200, model__reg_alpha=1.0, model__reg_lambda=0.5, model__subsample=1.0;, score=(train=-0.863, test=-0.866) total time=   0.1s
# [CV 4/5] END model__colsample_bytree=0.5, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=9, model__n_estimators=200, model__reg_alpha=1.0, model__reg_lambda=0.5, model__subsample=1.0;, score=(train=-0.857, test=-0.887) total time=   0.1s
# [CV 5/5] END model__colsample_bytree=0.5, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=9, model__n_estimators=200, model__reg_alpha=1.0, model__reg_lambda=0.5, model__subsample=1.0;, score=(train=-0.863, test=-0.862) total time=   0.1s
# [CV 1/5] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=11, model__min_child_weight=3, model__n_estimators=50, model__reg_alpha=0.1, model__reg_lambda=0.5, model__subsample=1.0;, score=(train=-0.571, test=-0.693) total time=   0.1s
# [CV 2/5] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=11, model__min_child_weight=3, model__n_estimators=50, model__reg_alpha=0.1, model__reg_lambda=0.5, model__subsample=1.0;, score=(train=-0.571, test=-0.695) total time=   0.1s
# [CV 3/5] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=11, model__min_child_weight=3, model__n_estimators=50, model__reg_alpha=0.1, model__reg_lambda=0.5, model__subsample=1.0;, score=(train=-0.573, test=-0.682) total time=   0.1s
# [CV 4/5] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=11, model__min_child_weight=3, model__n_estimators=50, model__reg_alpha=0.1, model__reg_lambda=0.5, model__subsample=1.0;, score=(train=-0.565, test=-0.704) total time=   0.2s
# [CV 5/5] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=11, model__min_child_weight=3, model__n_estimators=50, model__reg_alpha=0.1, model__reg_lambda=0.5, model__subsample=1.0;, score=(train=-0.573, test=-0.680) total time=   0.2s
# [CV 1/5] END model__colsample_bytree=0.75, model__learning_rate=0.5, model__max_depth=3, model__min_child_weight=9, model__n_estimators=300, model__reg_alpha=0.1, model__reg_lambda=1.0, model__subsample=0.75;, score=(train=-0.644, test=-0.669) total time=   0.1s
# [CV 2/5] END model__colsample_bytree=0.75, model__learning_rate=0.5, model__max_depth=3, model__min_child_weight=9, model__n_estimators=300, model__reg_alpha=0.1, model__reg_lambda=1.0, model__subsample=0.75;, score=(train=-0.644, test=-0.670) total time=   0.1s
# [CV 3/5] END model__colsample_bytree=0.75, model__learning_rate=0.5, model__max_depth=3, model__min_child_weight=9, model__n_estimators=300, model__reg_alpha=0.1, model__reg_lambda=1.0, model__subsample=0.75;, score=(train=-0.647, test=-0.667) total time=   0.1s
# [CV 4/5] END model__colsample_bytree=0.75, model__learning_rate=0.5, model__max_depth=3, model__min_child_weight=9, model__n_estimators=300, model__reg_alpha=0.1, model__reg_lambda=1.0, model__subsample=0.75;, score=(train=-0.641, test=-0.683) total time=   0.1s
# [CV 5/5] END model__colsample_bytree=0.75, model__learning_rate=0.5, model__max_depth=3, model__min_child_weight=9, model__n_estimators=300, model__reg_alpha=0.1, model__reg_lambda=1.0, model__subsample=0.75;, score=(train=-0.648, test=-0.661) total time=   0.2s
# [CV 1/5] END model__colsample_bytree=0.5, model__learning_rate=0.05, model__max_depth=3, model__min_child_weight=5, model__n_estimators=50, model__reg_alpha=0.5, model__reg_lambda=0, model__subsample=0.75;, score=(train=-0.818, test=-0.807) total time=   0.0s
# [CV 2/5] END model__colsample_bytree=0.5, model__learning_rate=0.05, model__max_depth=3, model__min_child_weight=5, model__n_estimators=50, model__reg_alpha=0.5, model__reg_lambda=0, model__subsample=0.75;, score=(train=-0.815, test=-0.821) total time=   0.0s
# [CV 3/5] END model__colsample_bytree=0.5, model__learning_rate=0.05, model__max_depth=3, model__min_child_weight=5, model__n_estimators=50, model__reg_alpha=0.5, model__reg_lambda=0, model__subsample=0.75;, score=(train=-0.817, test=-0.815) total time=   0.0s
# [CV 4/5] END model__colsample_bytree=0.5, model__learning_rate=0.05, model__max_depth=3, model__min_child_weight=5, model__n_estimators=50, model__reg_alpha=0.5, model__reg_lambda=0, model__subsample=0.75;, score=(train=-0.811, test=-0.840) total time=   0.0s
# [CV 5/5] END model__colsample_bytree=0.5, model__learning_rate=0.05, model__max_depth=3, model__min_child_weight=5, model__n_estimators=50, model__reg_alpha=0.5, model__reg_lambda=0, model__subsample=0.75;, score=(train=-0.818, test=-0.814) total time=   0.0s
# [CV 1/5] END model__colsample_bytree=1.0, model__learning_rate=0.3, model__max_depth=9, model__min_child_weight=9, model__n_estimators=100, model__reg_alpha=0.1, model__reg_lambda=0.5, model__subsample=0.5;, score=(train=-0.584, test=-0.717) total time=   0.2s
# [CV 2/5] END model__colsample_bytree=1.0, model__learning_rate=0.3, model__max_depth=9, model__min_child_weight=9, model__n_estimators=100, model__reg_alpha=0.1, model__reg_lambda=0.5, model__subsample=0.5;, score=(train=-0.585, test=-0.709) total time=   0.2s
# [CV 3/5] END model__colsample_bytree=1.0, model__learning_rate=0.3, model__max_depth=9, model__min_child_weight=9, model__n_estimators=100, model__reg_alpha=0.1, model__reg_lambda=0.5, model__subsample=0.5;, score=(train=-0.589, test=-0.694) total time=   0.2s
# [CV 4/5] END model__colsample_bytree=1.0, model__learning_rate=0.3, model__max_depth=9, model__min_child_weight=9, model__n_estimators=100, model__reg_alpha=0.1, model__reg_lambda=0.5, model__subsample=0.5;, score=(train=-0.583, test=-0.721) total time=   0.2s
# [CV 5/5] END model__colsample_bytree=1.0, model__learning_rate=0.3, model__max_depth=9, model__min_child_weight=9, model__n_estimators=100, model__reg_alpha=0.1, model__reg_lambda=0.5, model__subsample=0.5;, score=(train=-0.588, test=-0.696) total time=   0.2s
# [CV 1/5] END model__colsample_bytree=0.75, model__learning_rate=0.05, model__max_depth=3, model__min_child_weight=11, model__n_estimators=400, model__reg_alpha=1.0, model__reg_lambda=0.5, model__subsample=0.5;, score=(train=-0.668, test=-0.670) total time=   0.2s
# [CV 2/5] END model__colsample_bytree=0.75, model__learning_rate=0.05, model__max_depth=3, model__min_child_weight=11, model__n_estimators=400, model__reg_alpha=1.0, model__reg_lambda=0.5, model__subsample=0.5;, score=(train=-0.667, test=-0.677) total time=   0.2s
# [CV 3/5] END model__colsample_bytree=0.75, model__learning_rate=0.05, model__max_depth=3, model__min_child_weight=11, model__n_estimators=400, model__reg_alpha=1.0, model__reg_lambda=0.5, model__subsample=0.5;, score=(train=-0.668, test=-0.669) total time=   0.2s
# [CV 4/5] END model__colsample_bytree=0.75, model__learning_rate=0.05, model__max_depth=3, model__min_child_weight=11, model__n_estimators=400, model__reg_alpha=1.0, model__reg_lambda=0.5, model__subsample=0.5;, score=(train=-0.663, test=-0.696) total time=   0.2s
# [CV 5/5] END model__colsample_bytree=0.75, model__learning_rate=0.05, model__max_depth=3, model__min_child_weight=11, model__n_estimators=400, model__reg_alpha=1.0, model__reg_lambda=0.5, model__subsample=0.5;, score=(train=-0.669, test=-0.670) total time=   0.2s
# [CV 1/5] END model__colsample_bytree=1.0, model__learning_rate=0.5, model__max_depth=7, model__min_child_weight=11, model__n_estimators=200, model__reg_alpha=1.0, model__reg_lambda=0.5, model__subsample=0.5;, score=(train=-0.593, test=-0.716) total time=   0.2s
# [CV 2/5] END model__colsample_bytree=1.0, model__learning_rate=0.5, model__max_depth=7, model__min_child_weight=11, model__n_estimators=200, model__reg_alpha=1.0, model__reg_lambda=0.5, model__subsample=0.5;, score=(train=-0.592, test=-0.719) total time=   0.2s
# [CV 3/5] END model__colsample_bytree=1.0, model__learning_rate=0.5, model__max_depth=7, model__min_child_weight=11, model__n_estimators=200, model__reg_alpha=1.0, model__reg_lambda=0.5, model__subsample=0.5;, score=(train=-0.598, test=-0.703) total time=   0.2s
# [CV 4/5] END model__colsample_bytree=1.0, model__learning_rate=0.5, model__max_depth=7, model__min_child_weight=11, model__n_estimators=200, model__reg_alpha=1.0, model__reg_lambda=0.5, model__subsample=0.5;, score=(train=-0.594, test=-0.719) total time=   0.2s
# [CV 5/5] END model__colsample_bytree=1.0, model__learning_rate=0.5, model__max_depth=7, model__min_child_weight=11, model__n_estimators=200, model__reg_alpha=1.0, model__reg_lambda=0.5, model__subsample=0.5;, score=(train=-0.598, test=-0.707) total time=   0.2s
# [CV 1/5] END model__colsample_bytree=0.75, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=9, model__n_estimators=400, model__reg_alpha=0.1, model__reg_lambda=0.5, model__subsample=0.75;, score=(train=-0.628, test=-0.666) total time=   0.3s
# [CV 2/5] END model__colsample_bytree=0.75, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=9, model__n_estimators=400, model__reg_alpha=0.1, model__reg_lambda=0.5, model__subsample=0.75;, score=(train=-0.628, test=-0.669) total time=   0.3s
# [CV 3/5] END model__colsample_bytree=0.75, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=9, model__n_estimators=400, model__reg_alpha=0.1, model__reg_lambda=0.5, model__subsample=0.75;, score=(train=-0.632, test=-0.660) total time=   0.3s
# [CV 4/5] END model__colsample_bytree=0.75, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=9, model__n_estimators=400, model__reg_alpha=0.1, model__reg_lambda=0.5, model__subsample=0.75;, score=(train=-0.626, test=-0.682) total time=   0.3s
# [CV 5/5] END model__colsample_bytree=0.75, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=9, model__n_estimators=400, model__reg_alpha=0.1, model__reg_lambda=0.5, model__subsample=0.75;, score=(train=-0.630, test=-0.661) total time=   0.3s
# [CV 1/5] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=5, model__n_estimators=50, model__reg_alpha=0.1, model__reg_lambda=1.0, model__subsample=1.0;, score=(train=-1.404, test=-1.381) total time=   0.0s
# [CV 2/5] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=5, model__n_estimators=50, model__reg_alpha=0.1, model__reg_lambda=1.0, model__subsample=1.0;, score=(train=-1.400, test=-1.398) total time=   0.0s
# [CV 3/5] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=5, model__n_estimators=50, model__reg_alpha=0.1, model__reg_lambda=1.0, model__subsample=1.0;, score=(train=-1.400, test=-1.400) total time=   0.0s
# [CV 4/5] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=5, model__n_estimators=50, model__reg_alpha=0.1, model__reg_lambda=1.0, model__subsample=1.0;, score=(train=-1.396, test=-1.415) total time=   0.0s
# [CV 5/5] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=5, model__n_estimators=50, model__reg_alpha=0.1, model__reg_lambda=1.0, model__subsample=1.0;, score=(train=-1.398, test=-1.413) total time=   0.0s
# [CV 1/5] END model__colsample_bytree=0.5, model__learning_rate=0.1, model__max_depth=9, model__min_child_weight=5, model__n_estimators=300, model__reg_alpha=1.0, model__reg_lambda=0.1, model__subsample=0.5;, score=(train=-0.613, test=-0.678) total time=   0.3s
# [CV 2/5] END model__colsample_bytree=0.5, model__learning_rate=0.1, model__max_depth=9, model__min_child_weight=5, model__n_estimators=300, model__reg_alpha=1.0, model__reg_lambda=0.1, model__subsample=0.5;, score=(train=-0.614, test=-0.679) total time=   0.3s
# [CV 3/5] END model__colsample_bytree=0.5, model__learning_rate=0.1, model__max_depth=9, model__min_child_weight=5, model__n_estimators=300, model__reg_alpha=1.0, model__reg_lambda=0.1, model__subsample=0.5;, score=(train=-0.618, test=-0.670) total time=   0.4s
# [CV 4/5] END model__colsample_bytree=0.5, model__learning_rate=0.1, model__max_depth=9, model__min_child_weight=5, model__n_estimators=300, model__reg_alpha=1.0, model__reg_lambda=0.1, model__subsample=0.5;, score=(train=-0.611, test=-0.691) total time=   0.3s
# [CV 5/5] END model__colsample_bytree=0.5, model__learning_rate=0.1, model__max_depth=9, model__min_child_weight=5, model__n_estimators=300, model__reg_alpha=1.0, model__reg_lambda=0.1, model__subsample=0.5;, score=(train=-0.616, test=-0.671) total time=   0.3s
# [CV 1/5] END model__colsample_bytree=0.75, model__learning_rate=0.05, model__max_depth=11, model__min_child_weight=5, model__n_estimators=100, model__reg_alpha=0, model__reg_lambda=0, model__subsample=1.0;, score=(train=-0.592, test=-0.684) total time=   0.2s
# [CV 2/5] END model__colsample_bytree=0.75, model__learning_rate=0.05, model__max_depth=11, model__min_child_weight=5, model__n_estimators=100, model__reg_alpha=0, model__reg_lambda=0, model__subsample=1.0;, score=(train=-0.592, test=-0.688) total time=   0.2s
# [CV 3/5] END model__colsample_bytree=0.75, model__learning_rate=0.05, model__max_depth=11, model__min_child_weight=5, model__n_estimators=100, model__reg_alpha=0, model__reg_lambda=0, model__subsample=1.0;, score=(train=-0.594, test=-0.675) total time=   0.2s
# [CV 4/5] END model__colsample_bytree=0.75, model__learning_rate=0.05, model__max_depth=11, model__min_child_weight=5, model__n_estimators=100, model__reg_alpha=0, model__reg_lambda=0, model__subsample=1.0;, score=(train=-0.587, test=-0.699) total time=   0.2s
# [CV 5/5] END model__colsample_bytree=0.75, model__learning_rate=0.05, model__max_depth=11, model__min_child_weight=5, model__n_estimators=100, model__reg_alpha=0, model__reg_lambda=0, model__subsample=1.0;, score=(train=-0.594, test=-0.679) total time=   0.2s
# {'model__subsample': 0.75,
#  'model__reg_lambda': 0.5,
#  'model__reg_alpha': 0.1,
#  'model__n_estimators': 400,
#  'model__min_child_weight': 9,
#  'model__max_depth': 5,
#  'model__learning_rate': 0.1,
#  'model__colsample_bytree': 0.75}

# %%
# Print parameters of the best estimator
rcv_xgb.best_params_
# Out:
# {'model__subsample': 0.75,
#  'model__reg_lambda': 0.5,
#  'model__reg_alpha': 0.1,
#  'model__n_estimators': 400,
#  'model__min_child_weight': 9,
#  'model__max_depth': 5,
#  'model__learning_rate': 0.1,
#  'model__colsample_bytree': 0.75}

# %% [markdown]
# Very similar results as our Gradient Boost, our validation scores are slightly higher so this model might have a bit more variance. This model is also underfitting slighly more on our train/test data, with test scores nearly the same.

# %%
# Get train and test metrics
train_scores, xgb_best = rcv_metrics(rcv_xgb,'XGBoost',X_train,y_train,train_scores)
display(train_scores)

test_scores = test_metrics(xgb_best,'XGBoost',X_test,y_test,test_scores)
display(test_scores)
# Out:
#       Model Name  Val Train Score  Val Test Score
# 0          Lasso         1.382408        1.382881
# 1          Ridge         0.776968        0.777689
# 2       Ridge Sm         0.840484        0.842000
# 3       Decision         0.629059        0.740311
# 4         Forest         0.602695        0.681237
# 5  GradientBoost         0.669444        0.799089
# 6        XGBoost         0.713996        0.772146
#       Model Name  Train Score  Test Score
# 0          Lasso     0.776039    0.763157
# 1          Ridge     0.776040    0.763174
# 2       Ridge Sm     0.840221    0.828695
# 3       Decision     0.625636    0.688807
# 4         Forest     0.613752    0.674664
# 5  GradientBoost     0.653514    0.663821
# 6        XGBoost     0.633094    0.666100

# %% [markdown]
# ### AdaBoost
#
# The last boosting model we'll try is AdaBoost with our XGBoost as our base estimator since it had the best score with the least underfitting.

# %%
# Replace Regressor in pipeline

ada_pipe = ridge_pipe.set_params(model=AdaBoostRegressor(random_state=42,estimator=xgb_best['model']))
ada_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('subpipe_num',
#                                                   Pipeline(steps=[('num_impute',
#                                                                    SimpleImputer()),
#                                                                   ('ss',
#                                                                    StandardScaler())]),
#                                                   [3, 4, 5]),
#                                                  ('subpipe_cat',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   [0, 1, 2])])),
#                 ('model',
#                  AdaBoostRegressor(estimator=XGBRegressor(base_score=No...
#                                                           grow_policy=None,
#                                                           importance_type=None,
#                                                           interaction_constraints=None,
#                                                           learning_rate=0.1,
#                                                           max_bin=None,
#                                                           max_cat_threshold=None,
#                                                           max_cat_to_onehot=None,
#                                                           max_delta_step=None,
#                                                           max_depth=5,
#                                                           max_leaves=None,
#                                                           min_child_weight=9,
#                                                           missing=nan,
#                                                           monotone_constraints=None,
#                                                           multi_strategy=None,
#                                                           n_estimators=400,
#                                                           n_jobs=None,
#                                                           num_parallel_tree=None,
#                                                           random_state=42, ...),
#                                    random_state=42))])

# %%
# Randomizedsearch CV 

params_ada = {'model__learning_rate': [0.001, 0.01, 0.1, 0.2, 0.3],
          'model__n_estimators': [50, 100, 200, 300, 400],
          'model__loss': ['linear','square']
}

rcv_ada = RandomizedSearchCV(ada_pipe,param_distributions=params_ada,scoring='neg_root_mean_squared_error',
                        return_train_score=True,random_state=42,n_iter=3,verbose=3)

rcv_ada.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END model__learning_rate=0.01, model__loss=linear, model__n_estimators=300;, score=(train=-0.624, test=-0.667) total time= 1.4min
# [CV 2/5] END model__learning_rate=0.01, model__loss=linear, model__n_estimators=300;, score=(train=-0.624, test=-0.670) total time= 1.3min
# [CV 3/5] END model__learning_rate=0.01, model__loss=linear, model__n_estimators=300;, score=(train=-0.627, test=-0.659) total time= 1.4min
# [CV 4/5] END model__learning_rate=0.01, model__loss=linear, model__n_estimators=300;, score=(train=-0.622, test=-0.680) total time= 1.4min
# [CV 5/5] END model__learning_rate=0.01, model__loss=linear, model__n_estimators=300;, score=(train=-0.627, test=-0.662) total time= 1.4min
# [CV 1/5] END model__learning_rate=0.2, model__loss=square, model__n_estimators=400;, score=(train=-0.629, test=-0.673) total time=  12.3s
# [CV 2/5] END model__learning_rate=0.2, model__loss=square, model__n_estimators=400;, score=(train=-0.629, test=-0.678) total time=  12.1s
# [CV 3/5] END model__learning_rate=0.2, model__loss=square, model__n_estimators=400;, score=(train=-0.635, test=-0.667) total time=  13.0s
# [CV 4/5] END model__learning_rate=0.2, model__loss=square, model__n_estimators=400;, score=(train=-0.631, test=-0.686) total time=  11.7s
# [CV 5/5] END model__learning_rate=0.2, model__loss=square, model__n_estimators=400;, score=(train=-0.634, test=-0.674) total time=   9.6s
# [CV 1/5] END model__learning_rate=0.2, model__loss=linear, model__n_estimators=50;, score=(train=-0.628, test=-0.675) total time=  13.9s
# [CV 2/5] END model__learning_rate=0.2, model__loss=linear, model__n_estimators=50;, score=(train=-0.627, test=-0.680) total time=  14.2s
# [CV 3/5] END model__learning_rate=0.2, model__loss=linear, model__n_estimators=50;, score=(train=-0.632, test=-0.667) total time=  13.6s
# [CV 4/5] END model__learning_rate=0.2, model__loss=linear, model__n_estimators=50;, score=(train=-0.628, test=-0.686) total time=  13.6s
# [CV 5/5] END model__learning_rate=0.2, model__loss=linear, model__n_estimators=50;, score=(train=-0.631, test=-0.670) total time=  14.2s
# RandomizedSearchCV(estimator=Pipeline(steps=[('ct',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('subpipe_num',
#                                                                                Pipeline(steps=[('num_impute',
#                                                                                                 SimpleImputer()),
#                                                                                                ('ss',
#                                                                                                 StandardScaler())]),
#                                                                                [3,
#                                                                                 4,
#                                                                                 5]),
#                                                                               ('subpipe_cat',
#                                                                                Pipeline(steps=[('ohe',
#                                                                                                 OneHotEncoder(handle_unknown='ignore',
#                                                                                                               sparse_output=False))]),
#                                                                                [0,
#                                                                                 1,
#                                                                                 2])])),
#                                              ('model',
#                                               AdaBoostRegressor(estimat...
#                                                                                        multi_strategy=None,
#                                                                                        n_estimators=400,
#                                                                                        n_jobs=None,
#                                                                                        num_parallel_tree=None,
#                                                                                        random_state=42, ...),
#                                                                 random_state=42))]),
#                    n_iter=3,
#                    param_distributions={'model__learning_rate': [0.001, 0.01,
#                                                                  0.1, 0.2,
#                                                                  0.3],
#                                         'model__loss': ['linear', 'square'],
#                                         'model__n_estimators': [50, 100, 200,
#                                                                 300, 400]},
#                    random_state=42, return_train_score=True,
#                    scoring='neg_root_mean_squared_error', verbose=3)

# %%
rcv_ada.best_params_
# Out:
# {'model__n_estimators': 300,
#  'model__loss': 'linear',
#  'model__learning_rate': 0.01}

# %% [markdown]
# Adaboost is doing slightly better than XGBoost, but not by much. It is still also still slightly underfitting.

# %%
# Get train and test metrics
train_scores, ada_best = rcv_metrics(rcv_ada,'AdaBoost',X_train,y_train,train_scores)
display(train_scores)

test_scores = test_metrics(ada_best,'AdaBoost',X_test,y_test,test_scores)
display(test_scores)
# Out:
#       Model Name  Val Train Score  Val Test Score
# 0          Lasso         1.382408        1.382881
# 1          Ridge         0.776968        0.777689
# 2       Ridge Sm         0.840484        0.842000
# 3       Decision         0.629059        0.740311
# 4         Forest         0.602695        0.681237
# 5  GradientBoost         0.669444        0.799089
# 6        XGBoost         0.713996        0.772146
# 7       AdaBoost         0.628571        0.672999
#       Model Name  Train Score  Test Score
# 0          Lasso     0.776039    0.763157
# 1          Ridge     0.776040    0.763174
# 2       Ridge Sm     0.840221    0.828695
# 3       Decision     0.625636    0.688807
# 4         Forest     0.613752    0.674664
# 5  GradientBoost     0.653514    0.663821
# 6        XGBoost     0.633094    0.666100
# 7       AdaBoost     0.630011    0.663476

# %% [markdown]
# ## 8. Averaging & Weighted Avereging
#
# Lastly, we will take some of our best models and create combined models to see if we can get the best out of all of them.

# %% [markdown]
# ### VotingRegressor

# %%
# Create weighted averaging 

estimators = [
    ('gb',gradient_best),
    ('xgb',xgb_best),
    ('ada',ada_best)
]

voting_pipe = ridge_pipe.set_params(model=VotingRegressor(estimators=estimators, weights=[.2,.35,.45]))

voting_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('subpipe_num',
#                                                   Pipeline(steps=[('num_impute',
#                                                                    SimpleImputer()),
#                                                                   ('ss',
#                                                                    StandardScaler())]),
#                                                   [3, 4, 5]),
#                                                  ('subpipe_cat',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   [0, 1, 2])])),
#                 ('model',
#                  VotingRegressor(estimators=[('gb',
#                                               Pipeline(steps=[('ct...
#                                                                                                         learning_rate=0.1,
#                                                                                                         max_bin=None,
#                                                                                                         max_cat_threshold=None,
#                                                                                                         max_cat_to_onehot=None,
#                                                                                                         max_delta_step=None,
#                                                                                                         max_depth=5,
#                                                                                                         max_leaves=None,
#                                                                                                         min_child_weight=9,
#                                                                                                         missing=nan,
#                                                                                                         monotone_constraints=None,
#                                                                                                         multi_strategy=None,
#                                                                                                         n_estimators=400,
#                                                                                                         n_jobs=None,
#                                                                                                         num_parallel_tree=None,
#                                                                                                         random_state=42, ...),
#                                                                                  learning_rate=0.01,
#                                                                                  n_estimators=300,
#                                                                                  random_state=42))]))],
#                                  weights=[0.2, 0.35, 0.45]))])

# %%
# Randomizedsearch CV 

params_voting = {'model__weights': [[.2,.35,.45],[.2,.4,.4],[.1,.45,.45], [.1,.40,.50]]
}

rcv_voting = RandomizedSearchCV(voting_pipe,param_distributions=params_voting,scoring='neg_root_mean_squared_error',
                        return_train_score=True,random_state=42,n_iter=2,verbose=3)

rcv_voting.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END model__weights=[0.2, 0.4, 0.4];, score=(train=-0.704, test=-0.736) total time= 1.8min
# [CV 2/5] END model__weights=[0.2, 0.4, 0.4];, score=(train=-0.700, test=-0.746) total time= 1.9min
# [CV 3/5] END model__weights=[0.2, 0.4, 0.4];, score=(train=-0.703, test=-0.735) total time= 2.2min
# [CV 4/5] END model__weights=[0.2, 0.4, 0.4];, score=(train=-0.699, test=-0.756) total time= 2.1min
# [CV 5/5] END model__weights=[0.2, 0.4, 0.4];, score=(train=-0.703, test=-0.728) total time= 1.9min
# [CV 1/5] END model__weights=[0.1, 0.4, 0.5];, score=(train=-0.693, test=-0.727) total time= 1.9min
# [CV 2/5] END model__weights=[0.1, 0.4, 0.5];, score=(train=-0.690, test=-0.738) total time= 1.9min
# [CV 3/5] END model__weights=[0.1, 0.4, 0.5];, score=(train=-0.693, test=-0.726) total time= 1.9min
# [CV 4/5] END model__weights=[0.1, 0.4, 0.5];, score=(train=-0.688, test=-0.747) total time= 2.1min
# [CV 5/5] END model__weights=[0.1, 0.4, 0.5];, score=(train=-0.692, test=-0.720) total time= 2.0min
# RandomizedSearchCV(estimator=Pipeline(steps=[('ct',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('subpipe_num',
#                                                                                Pipeline(steps=[('num_impute',
#                                                                                                 SimpleImputer()),
#                                                                                                ('ss',
#                                                                                                 StandardScaler())]),
#                                                                                [3,
#                                                                                 4,
#                                                                                 5]),
#                                                                               ('subpipe_cat',
#                                                                                Pipeline(steps=[('ohe',
#                                                                                                 OneHotEncoder(handle_unknown='ignore',
#                                                                                                               sparse_output=False))]),
#                                                                                [0,
#                                                                                 1,
#                                                                                 2])])),
#                                              ('model',
#                                               VotingRegressor(estimator...
#                                                                                                                                      n_estimators=400,
#                                                                                                                                      n_jobs=None,
#                                                                                                                                      num_parallel_tree=None,
#                                                                                                                                      random_state=42, ...),
#                                                                                                               learning_rate=0.01,
#                                                                                                               n_estimators=300,
#                                                                                                               random_state=42))]))],
#                                                               weights=[0.2,
#                                                                        0.35,
#                                                                        0.45]))]),
#                    n_iter=2,
#                    param_distributions={'model__weights': [[0.2, 0.35, 0.45],
#                                                            [0.2, 0.4, 0.4],
#                                                            [0.1, 0.45, 0.45],
#                                                            [0.1, 0.4, 0.5]]},
#                    random_state=42, return_train_score=True,
#                    scoring='neg_root_mean_squared_error', verbose=3)

# %%
# Print parameters of the beast estimator
rcv_voting.best_params_
# Out:
# {'model__weights': [0.1, 0.4, 0.5]}

# %% [markdown]
# Our Voting Regressor did slightly worse than our GradientBoost and XGBoost and is overfitting slightly more.

# %% [markdown]
# Our AdaBoost is still our best model, the VotingRegressor did adjust the underfitting, but not significantly.

# %%
# Get train and test metrics
train_scores, voting_best = rcv_metrics(rcv_voting,'Voting',X_train,y_train,train_scores)
display(train_scores)

test_scores = test_metrics(voting_best,'Voting',X_test,y_test,test_scores)
display(test_scores)
# Out:
#       Model Name  Val Train Score  Val Test Score
# 0          Lasso         1.382408        1.382881
# 1          Ridge         0.776968        0.777689
# 2       Ridge Sm         0.840484        0.842000
# 3       Decision         0.629059        0.740311
# 4         Forest         0.602695        0.681237
# 5  GradientBoost         0.669444        0.799089
# 6        XGBoost         0.713996        0.772146
# 7       AdaBoost         0.628571        0.672999
# 8         Voting         0.696387        0.736033
#       Model Name  Train Score  Test Score
# 0          Lasso     0.776039    0.763157
# 1          Ridge     0.776040    0.763174
# 2       Ridge Sm     0.840221    0.828695
# 3       Decision     0.625636    0.688807
# 4         Forest     0.613752    0.674664
# 5  GradientBoost     0.653514    0.663821
# 6        XGBoost     0.633094    0.666100
# 7       AdaBoost     0.630011    0.663476
# 8         Voting     0.691590    0.720550

# %% [markdown]
# ### StackingRegressor
#
# As our last ensemble model, we will try stacking our best models.

# %%
# replace in pipe

estimators = [
    ('gb',gradient_best),
    ('xgb',xgb_best),
    ('ada',ada_best)
]

stacking_pipe = ridge_pipe.set_params(model=StackingRegressor(estimators=estimators))

stacking_pipe.fit(X_train,y_train)

# %%
# Randomizedsearch CV 

params_stacking = {'model__final_estimator': [xgb_best['model'],ada_best['model']]
}

rcv_stacking = RandomizedSearchCV(stacking_pipe,param_distributions=params_stacking,scoring='neg_root_mean_squared_error',
                        return_train_score=True,random_state=42,n_iter=2,verbose=3)

rcv_stacking.fit(X_train,y_train)

# %%
# Print parameters of the beast estimator
rcv_stacking.best_params_

# %% [markdown]
# Looks like Stacking gives us around the same results as Voting! It is also overfitting on the validation data.

# %%
# Get train and test metrics
train_scores, stacking_best = rcv_metrics(rcv_stacking,'Stacking',X_train,y_train,train_scores)
display(train_scores)

test_scores = test_metrics(stacking_best,'Stacking',X_test,y_test,test_scores)
display(test_scores)
